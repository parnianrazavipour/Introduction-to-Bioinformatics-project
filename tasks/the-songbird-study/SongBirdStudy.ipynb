# %% [markdown]
# # Final Project of Introduction to Bioinformatics
#
# ## The Song Bird Study

# %% [markdown]
# <div style="text-align: center;">
#     <img src="SocialNetworking.png" width="350">
# </div>

# %% [markdown]
# ### Introduction
#
# #### Investigating the Influence of Social Environment on Neural Responses to Sickness in Zebra Finches: A Bioinformatics Approach
#
# The Zebra Finch, _Taeniopygia guttata_, a widely used model organism in behavioral and neurobiological research, provides an excellent platform to study the interplay between social environment, neural function, and immune response. In this project, we delve into an intriguing scientific question: How does the social environment of these birds modulate their neural response to immune challenges?
#
# This question was explored in a study by Lopes PC, Faber-Hammond JJ, Siemonsma C, Patel S, and Renn SCP, titled _"The social environment alters neural responses to a lipopolysaccharide challenge"_ (Brain Behav Immun 2023). Their research demonstrated that the social environment, particularly the presence of conspecifics, could significantly modulate the neural responses of Zebra Finches to immune challenges such as lipopolysaccharide (LPS), a molecule known to induce immune responses. Link to Paper
#
# Our goal in this notebook is to revisit and build upon the findings of this study. Using RNA sequencing data from their research, we aim to conduct a comprehensive analysis of changes in gene expression across different brain regions of Zebra Finches under different social conditions. We will specifically focus on the hypothalamus, the bed nucleus of the stria terminalis, and the nucleus taeniae, all of which are key regions for understanding behavior and immune response.
#
# The essence of this project is to draw meaningful insights from high-dimensional data. We encourage you to start with basic approaches and gradually build complexity. Remember, every effort to extract information and gain insights from the data is valuable and will be recognized. Approach the tasks with curiosity and an open mind, and let your analytical journey be both informative and enjoyable.
#
# ---

# %% [markdown]
# ### Experiment Design
#
# The primary aim of this high-throughput sequencing study was to discern how different social environments could modulate the neural response to sickness induced by lipopolysaccharide (LPS).
#
# **Lipopolysaccharide (LPS)** is a large molecule consisting of a lipid and a polysaccharide, found in the outer membrane of Gram-negative bacteria. It is often referred to as an endotoxin due to its ability to trigger strong immune responses. When a Gram-negative bacterium dies, it releases its LPS, which can then find its way into the bloodstream. In the context of this study, LPS was used to simulate an immune challenge or sickness in the Zebra Finches.
#
# **The Experimental Setup:**
#
# The experiment involved male Zebra Finches, which were administered either an LPS injection to simulate sickness or a control solution. Following the injection, the birds were placed in one of four distinct social contexts:
#
# - **Isolated (ISO)**: In this setting, the birds were kept alone without a female. This condition was designed to examine the neural and immune responses of the birds in the absence of any social interactions. This group helps to understand the baseline responses to the LPS challenge when there are no social factors at play.
# - **Known Female Continuous (KFC)**: Here, the birds were continuously housed with a known female. This condition allowed the researchers to investigate the effects of a stable social environment on the birds' responses to the LPS challenge. This group can provide insights into how ongoing social interactions might influence the response to sickness.
# - **Known Female Reunited (KF)**: In this scenario, the birds were reunited with a known female after a period of separation. This condition was intended to mimic the effects of a disrupted social environment followed by a reunion. This group can shed light on how changes in social relationships might affect the neural and immune responses to sickness.
# - **Novel Female (NF)**: In this context, the birds were paired with a previously unknown female. This condition was designed to explore the effects of introducing a new social partner on the birds' responses to the LPS challenge. This group can reveal how novel social encounters might modulate the response to sickness.
#
# These social settings were carefully chosen to represent a range of social interactions that the birds might encounter in their natural habitats. The experimental design allows for a comprehensive investigation of how social environment influences the neural responses to sickness, thereby improving our understanding of how the social environment can affect health.
#
# ---

# %% [markdown]
# ### Understanding RNA-Seq
#
# RNA-Seq (RNA sequencing) is a powerful technique that uses next-generation sequencing (NGS) to reveal the presence and quantity of RNA molecules in a biological sample. It provides a snapshot of gene expression, also known as the transcriptome.
#
# **What is RNA-Seq?**
#
# RNA-Seq allows us to investigate and discover the transcriptome, which is the total cellular content of RNAs including mRNA, rRNA, and tRNA. Understanding the transcriptome is key if we are to connect the information in our genome with its functional protein expression. RNA-Seq can tell us which genes are turned on in a cell, what their level of transcription is, and at what times they are activated or shut off. This allows scientists to understand the biology of a cell more deeply and assess changes that may indicate disease.
#
# **How does RNA-Seq work?**
#
# The RNA-Seq workflow has several steps:
#
# 1. **RNA extraction**: The first step involves extracting the total RNA from the sample.
# 2. **Reverse transcription into cDNA**: The extracted RNA is then converted into complementary DNA (cDNA) through a process called reverse transcription.
# 3. **Library preparation**: The cDNA is then used to prepare a sequencing library. This involves fragmenting the cDNA, adding sequencing adapters, and amplifying the library.
# 4. **Sequencing**: The prepared library is then sequenced using high-throughput sequencing technology.
#
# **RNA-Seq Data**
#
# The output of an RNA-Seq experiment is a large set of short DNA sequences, or reads. These reads can be aligned to a reference genome to determine which genes were being transcribed at the time the sample was collected. The number of reads aligning to a particular gene provides a measure of that gene's expression level.
#
# **RNA-Seq vs Microarrays**
#
# RNA-Seq has several advantages over microarray technology, a legacy technology often used in gene expression studies. Unlike microarrays, which require species- or transcript-specific probes, RNA-Seq does not require any prior knowledge about the sequences of the transcripts. This allows RNA-Seq to detect novel transcripts, gene fusions, single nucleotide variants, indels (small insertions and deletions), and other previously unknown changes. RNA-Seq also has a wider dynamic range and higher sensitivity compared to microarrays, making it better at detecting transcripts and specifically isoforms.
#
# <blockquote style="font-family:Arial; color:red; font-size:16px; border-left:0px solid red; padding: 10px;">
#     <strong>Don't forget to answer these questions!</strong>
# </blockquote>
#
# **Questions**
#
# 1. Why is it important to convert RNA into cDNA for RNA-Seq? What would happen if we tried to sequence RNA directly?
# 2. How does the process of preparing a sequencing library contribute to the accuracy of RNA-Seq results? What are some potential sources of error in this step?
# 3. How does the ability of RNA-Seq to detect novel transcripts contribute to our understanding of gene function? Can you think of a scenario where this capability would be particularly useful?
# 4. Why might a researcher choose to use RNA-Seq instead of microarrays for a gene expression study? What are some potential advantages and disadvantages of each method?
#
#
# **_Your Answer:_**:
#
# **1.** There are multiple reasons that can be pointed out for the following cases:
# - Most sequencing technologies work with DNA libraries, so it is necessary to convert RNA to DNA.
# - Since DNA has greater stability compared to RNA, it allows for its amplification and prevents degradation during the sequencing process.
# - In RNA analysis, our goal is to study mRNA, but rRNA can dominate the sequencing process. By converting it to DNA, selective sequencing of the desired mRNA can be performed.
#
# **2.** Reasons why this step can help accuracy are as follows:
# - As mentioned in the previous section, the presence of rRNA can affect the results, so Ribo-depletion removes these rRNAs.
# - Since mRNAs usually have poly-A tails, in the Poly-A selection step, we can enrich for mRNAs to obtain a more accurate result.
# - The Size selection step allows for the isolation of specific RNA species based on their length, such as microRNAs.
# - In the Duplex-specific nuclease step, by helping to remove rRNAs that can reduce accuracy, we contribute to obtaining a more accurate result.
# Regarding potential errors that may occur in this process, we can also refer to the following points:
# - There is a possibility of RNA degradation during the process, which can lead to incorrect final results.
# - In the PCR amplification stages, if not optimized, high PCR duplication ratios can be produced, leading to an increase in the number of duplicates and bias.
# - There is a possibility of contamination from environmental sources used in the RNA-Seq stages, which can lead to errors.
# - Errors that may occur in Reverse transcriptase can also affect the accuracy of the result.
#
# **3.** Prior to RNA-Seq, gene annotation was largely based on computational predictions and limited experimental evidence. However, RNA-Seq provides a direct and efficient method for comprehensive profiling of the transcriptome, including both known and previously undiscovered transcripts. This capability can be useful to us in the following ways:
# - The RNA-Seq method helps us find and describe new types of RNA molecules that were previously unknown.
# - The RNA-Seq method shows us that genes can produce different versions of their RNA molecules by mixing and matching different parts.
# - The RNA-Seq method helps us identify genes that have often fused together as a result of genetic changes in diseases like cancer. This gives us insights into the underlying causes of diseases, which can be very helpful.
# - The RNA-Seq method helps us discover and study RNA molecules that do not produce proteins but still have an important role in regulating gene activity (non-coding RNAs).
#
# The above aspects can be useful for our understanding of how genes are controlled and for finding the underlying causes of diseases.
# It can also be useful in the following scenarios:
#
# - Identifying disease processes: By identifying novel transcripts, researchers can identify tissue-specific genes or isoforms that contribute to specialized functions or disease processes in specific tissues.
# - Investigating rare diseases and genetic disorders: In cases where the genetic basis of a rare disease or genetic disorder is not well understood, RNA-Seq, with its ability to detect new RNAs, can help identify new transcripts that may be involved.
# - Studying developmental processes: RNA-Seq can provide insights into gene expression dynamics during different stages of development. It can uncover previously unknown genes or isoforms that are involved in critical developmental processes.
#
# **4.** In this paragraph, we will discuss the benefits and drawbacks of each of these two methods that can help researchers make their decision in choosing between them:
#
# Advantages of RNA-Seq:
# - Higher sensitivity and dynamic range: RNA-Seq has a higher sensitivity that allows for the detection of genes with low expression and provides a wider dynamic range of gene expression measurements compared to microarrays. Therefore, they are more useful for identifying genes with lower expression levels.
# - Detection of novel transcripts and splice variants: RNA-Seq enables the discovery of novel transcripts and splice variants that may not be represented in microarrays, allowing researchers to identify previously unknown genes and isoforms.
# - Quantification of gene expression levels: RNA-Seq provides absolute quantification of gene expression levels and allows for more precise measurements compared to microarrays, which heavily rely on relative hybridization.
# - Identification of fusion genes: RNA-Seq can identify fusion genes resulting from chromosomal rearrangements and provide valuable insights into cancer research, genetic disorders, and regulatory mechanisms.
# - Ability to study non-coding RNAs: As mentioned in previous questions, RNA-Seq allows for the identification of non-coding RNAs, including microRNAs. Microarrays are limited in their ability to capture such non-coding RNA species.
#
# Disadvantages of RNA-Seq:
# - Higher cost and complexity: RNA-Seq is generally more expensive and computationally intensive compared to microarrays.
# - Higher storage and data processing requirements: Due to the large amount of sequence data generated, RNA-Seq requires significant storage and computational resources for data storage, processing, and analysis.
#
# Advantages of microarrays:
# - Lower cost: Microarrays are generally more cost-effective than RNA-Seq, making them a suitable option for gene expression studies on a large scale with limited budgets.
# Established technology and standardized protocols: Microarrays have been widely used for gene expression studies for years, so they have standardized protocols and available analysis pipelines that aid in data interpretation and comparison.
# - Lower computational complexity: Data analysis for microarrays is usually less computationally intensive compared to RNA-Seq, as it involves simpler data processing steps and does not require extensive bioinformatics expertise.
#
# Disadvantages of microarrays:
# - Limited dynamic range and sensitivity: Microarrays have a narrower dynamic range and lower sensitivity compared to RNA-Seq, which can result in reduced accuracy in detecting low-expression genes or subtle gene expression changes.
#
# Inability to detect novel transcripts and alternative splicing events: Microarrays are designed based on known gene annotations, which limits their ability to capture novel transcripts, alternative splicing events, or alternative fusion events.
# In general, it can be understood that the RNA-Seq method has higher accuracy compared to microarray, but microarray is a less expensive, faster, and more convenient method. Researchers should choose one of the methods based on their budget constraints and the level of accuracy they require.
#
# ---

# %% [markdown]
# ### Step 0: Installing Necessary Packages

# %%
import sys
import subprocess
import pkg_resources

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

REQUIRED_PACKAGES = [
    'biopython',
    'pandas',
    'numpy',
    'matplotlib',
    'seaborn',
    'xlrd',
    'mygene'
]

for package in REQUIRED_PACKAGES:
    try:
        dist = pkg_resources.get_distribution(package)
        print('{} ({}) is installed'.format(dist.key, dist.version))
    except pkg_resources.DistributionNotFound:
        print('{} is NOT installed'.format(package))
        install(package)
        print('{} was successfully installed.'.format(package))
# Out:
# biopython (1.81) is installed
# pandas (2.1.3) is installed
# numpy (1.26.1) is installed
# matplotlib (3.8.1) is installed
# seaborn (0.13.2) is installed
# xlrd (2.0.1) is installed
# mygene (3.2.2) is installed

# %%
# Import necessary libraries. 
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Loading the Dataset: A First Glimpse into the Zebra Finch's World
#
# With our tools at the ready, let's embark on the initial phase of our exploration. We'll load the dataset containing the read counts from the Zebra Finch RNA-Seq study and begin to unravel the secrets it holds.

# %%
# Loading the RNA-Seq read count data
dataset_path = './dataset/GSE203528_readcount.xls'
df_read_counts = pd.read_csv(dataset_path, sep='\t')


display(df_read_counts.head())
# Out:
#                geneID  HY3  HY4  HY5  HY6  HY8  HY9  HY12  HY13  HY14  ...  \
# 0  ENSTGUG00000008284  145  113  149  121  159  172   133   153   192  ...
# 1  ENSTGUG00000003938   25   18   21   29   22   38    23    34    35  ...
# 2  ENSTGUG00000011987  915  681  938  638  900  749   736   717   657  ...
# 3  ENSTGUG00000017592    5    5    5   14    5    4    22    13    11  ...
# 4  ENSTGUG00000009442  226  211  221  257  202  197   231   201   263  ...
#
#    TN62  TN63  TN64  TN65  TN66  TN67  TN68  TN69  TN70  TN71
# 0   114   111   185   144   134   158   105   143   116   161
# 1    27    52    63    92    31    52    44    53    33    40
# 2   710  1360  1277  1291   554  1225   956  1166   571   936
# 3     3     1     2     5     5     3    11     5    13     2
# 4   271   273   423   226   242   216   365   414   313   316
#
# [5 rows x 135 columns]

# %% [markdown]
# #### Exploring the Zebra Finch RNA-Seq Data
#
# In this RNA-Seq dataset, we delve into the complex world of the Zebra Finch by examining gene expression in three distinct areas of the brain: the hypothalamus, the bed nucleus of the stria terminalis, and the nucleus taeniae. Each of these regions plays a unique role in bird behavior and physiology.
#
# - **The Hypothalamus** (HY samples): This region is crucial for controlling hormones and basic survival functions like feeding, fighting, fleeing, and reproduction.
# - **The Bed Nucleus of the Stria Terminalis** (NST samples): This area is involved in the bird's stress response and emotional behavior.
# - **The Nucleus Taeniae** (TN samples): An area of the brain unique to birds, thought to be involved in social behaviors and possibly song learning.
#
# These regions were likely chosen for their significant roles in behaviors that are crucial for survival and species-specific activities. By analyzing gene expression in these areas, researchers can gain insights into how these regions contribute to the unique behaviors of the Zebra Finch.
#
# **Dataset Breakdown**
#
# Each row in the dataset represents a different gene, identified by a geneID like `ENSTGUG00000008284`. The columns, labeled with codes like `HY3`, `HY4`, `NST3`, etc., correspond to samples from these three brain regions. The numbers are read counts, indicating how often each gene's RNA was detected in the sample. High numbers suggest a gene is very active in that sample.
#
# These numbers are crucial. They tell us how active each gene was in each sample. The higher the number, the more active the gene. By comparing these numbers across different samples, we can get insights into how gene activity varies in different situations or conditions.
#
# <blockquote style="font-family:Arial; color:red; font-size:16px; border-left:0px solid red; padding: 10px;">
#     <strong>Don't forget to answer these questions!</strong>
# </blockquote>
#
# **Questions**
#
# 1. Why do you think the read counts vary between different genes in the same sample? What biological factors might contribute to this variation?
# 2. Can you think of any reasons why the read counts for the same gene might vary between different samples? Consider the experimental design and the nature of biological systems.
# 3. How would you interpret a situation where a gene has a high read count in one sample and a low read count in another? What might this tell us about the gene's role in the Zebra Finch's response to its social environment and the LPS challenge?
#
#
# **answer**
#
# **1.** The variation in read counts between different genes in the same sample can be attributed to several biological factors:
# - Gene length: Clearly, longer genes typically have more RNA molecules, which leads to higher read counts.
# - Gene expression regulation: Different genes have specific regulatory mechanisms that control their expression levels. For example, some genes may be actively transcribed and produce a higher number of RNA molecules, resulting in higher read counts.
# - Possibility of errors: Errors that occur during the RNA-Seq process may contribute to differences in read counts.
# - Biological function: Genes involved in essential cellular processes may have higher read counts.
# Transcription factors and regulatory elements: Gene expression can be influenced by transcription factors and regulatory elements that bind to specific DNA sequences. Variations in these factors can lead to differences in gene expression levels and subsequently affect read counts.
# - Alternative splicing and isoform diversity: Genes can undergo alternative splicing, resulting in the production of multiple RNA isoforms. Each isoform may have different read counts depending on its abundance. Additionally, some genes may have multiple copies or alleles, contributing to variation in read counts.
# - Biological variability: Biological variability between individuals or biological conditions can also contribute to differences in gene expression and, consequently, the observed read counts.
#
# **2.** Given the experimental design and the nature of biological systems, there are several reasons why the read counts for the same gene might vary between different samples:
# - Biological variability: Biological systems are inherently diverse, and gene expression can vary between individuals, even within the same species, due to factors such as genetic variations, epigenetic modifications, and differences in environmental factors or age. These variations can lead to differences in read counts for the same gene.
# - Tissue-specific expression: Gene expression can vary across different tissues and cell types. The samples in the RNA-Seq dataset are derived from distinct brain regions, each with its own cellular composition and specific gene expression profile. Therefore, the read counts for the same gene can differ between samples due to tissue-specific expression patterns.
# - Experimental conditions: Differences in experimental conditions can impact the accuracy and consistency of read counts between samples. Factors such as sample preparation, RNA extraction, library preparation, and sequencing protocols can introduce variation in read counts.
# - Biological conditions or treatments: If the samples represent different biological conditions or experimental treatments, gene expression can be influenced by these factors. For example, the studied brain regions may respond differently to specific stimuli, stressors, or hormonal changes, resulting in variations in read counts for specific genes between samples.
# - Random sampling variation: RNA-Seq relies on sampling a subset of RNA molecules from the total pool, and thus, there is inherent randomness in the process. This random sampling variation can contribute to differences in read counts for the same gene between samples, even if the underlying gene expression levels are similar.
# - Technical variation: Various technical factors, such as sequencing depth, read alignment algorithms, and normalization methods, can introduce variability in read counts.
#
#
# **3.** If a gene has a high read count in one sample and a low read count in another, it suggests differential gene expression between the two samples. This difference in read counts could provide insights into the gene's role in the Zebra Finch's response to its social environment and the LPS challenge. Here are a few possible interpretations:
#
# - Differential regulation: The gene may be differentially regulated in response to the social environment and the LPS challenge. A high read count in one sample could indicate that the gene is actively expressed and playing a significant role in the specific context of that sample. Conversely, a low read count in another sample suggests that the gene may not be as crucial or may be suppressed in that particular condition.
#
# - Biomarker potential: The gene with differential read counts could potentially serve as a biomarker for distinguishing between different states or conditions. For example, a high read count in the sample representing a specific social environment or LPS challenge could indicate the gene's association with that condition. This information could be valuable for further understanding the molecular mechanisms underlying the Zebra Finch's response to its social environment and LPS challenge.
#
# - Functional relevance: The gene with varying read counts may be functionally relevant to Zebra Finch's response. High read counts in one sample could suggest that the gene is actively involved in biological processes or pathways associated with the specific social environment or LPS challenge. Conversely, low read counts in another sample may imply that the gene's contribution to those processes or pathways is reduced or not as prominent.
#
# **Before proceeding, it's essential to ensure you have a foundational understanding of RNA-Seq, the objectives and design of the experiment we're examining, and the significance of each cell in the dataset. Grasping these concepts is crucial for successfully navigating the tasks ahead.**
#
# ---

# %% [markdown]
# ## Preprocessing and Normalization
#
# In this section, we begin our data analysis by focusing on preprocessing and normalization. Preprocessing involves converting the raw Ensembl gene IDs into more recognizable gene symbols, enhancing the interpretability of our data. Following this, normalization is performed to adjust for variations in sequencing depth and gene length, a crucial step to ensure accurate comparison of gene expression across different samples.

# %% [markdown]
# ### Transforming and Merging the Dataset for Analysis
#
# To facilitate our analysis, we need to restructure the gene expression data so that each row corresponds to a sample, with appropriate labels for social settings and tissue types. This transformation will enable us to apply machine learning techniques and conduct more effective analyses.
#
# The process involves two main steps:
# 1. **Transpose the Gene Expression Data**: Convert the gene expression data so that each row represents a sample and each column corresponds to a gene.
# 2. **Merge with Sample Mapping**: Combine the transposed gene expression data with the `sample_mapping.csv` to add social setting, study group, and tissue type information to each sample.
#
# This approach will create a dataset better suited for exploratory data analysis, clustering, and other statistical methods.

# %%
import pandas as pd

# Load the gene expression data
expression_data = pd.read_csv('./dataset/GSE203528_readcount.xls', sep='\t')

# Transpose the dataframe so that columns become rows and vice versa
transposed_df = expression_data.set_index('geneID').T.reset_index()
transposed_df.rename(columns={'index': 'tissue_id'}, inplace=True)

# Load the sample mapping data
sample_mapping = pd.read_csv('./dataset/sample_mappings.csv')

# Merge the transposed gene expression data with the sample mapping
merged_df = pd.merge(transposed_df, sample_mapping, on='tissue_id')

# Reorder columns to place metadata columns at the front
data = ['sample_id', 'social_settting', 'study_group', 'tissue_id']
gene_columns = [col for col in merged_df.columns if col not in data]
transformed_df = merged_df[data + gene_columns]

# Save the transformed and merged dataset
transformed_df.to_csv('./dataset/transformed_dataset.csv', index=False)

# Display the first few rows of the transformed dataset
display(transformed_df.head())
# Out:
#     sample_id social_settting study_group tissue_id  ENSTGUG00000008284  \
# 0  GSM6175777              NF           L       HY3                 145
# 1  GSM6175779             ISO           S       HY5                 149
# 2  GSM6175780             ISO           L       HY6                 121
# 3  GSM6175781             ISO           L       HY8                 159
# 4  GSM6175782             ISO           L       HY9                 172
#
#    ENSTGUG00000003938  ENSTGUG00000011987  ENSTGUG00000017592  \
# 0                  25                 915                   5
# 1                  21                 938                   5
# 2                  29                 638                  14
# 3                  22                 900                   5
# 4                  38                 749                   4
#
#    ENSTGUG00000009442  ENSTGUG00000009764  ...  ENSTGUG00000010786  \
# 0                 226                  94  ...                 443
# 1                 221                  76  ...                 327
# 2                 257                 126  ...                 350
# 3                 202                 178  ...                 418
# 4                 197                  94  ...                 274
#
#    ENSTGUG00000004644  ENSTGUG00000006386  ENSTGUG00000017785  \
# 0                 493                 722                   0
# 1                 433                 523                   0
# 2                 370                 395                   0
# 3                 435                 389                   0
# 4                 342                 291                   0
#
#    ENSTGUG00000001573  ENSTGUG00000014656  ENSTGUG00000003563  \
# 0                   0                   0                1473
# 1                   0                   0                1522
# 2                   2                   1                1320
# 3                  26                   5                1542
# 4                   0                   5                1267
#
#    ENSTGUG00000002845  ENSTGUG00000009990  ENSTGUG00000001666
# 0                  43                 276                 181
# 1                  37                 145                 118
# 2                  22                 174                 110
# 3                  57                 219                 116
# 4                  24                 157                  88
#
# [5 rows x 18622 columns]

# %% [markdown]
# ### Converting Ensembl IDs to Gene Names (Bonus)
#
# In our dataset, genes are currently identified by Ensembl IDs. While these IDs are precise, they may not be as immediately recognizable as standard gene names. For those interested in working with more familiar gene names, there's a straightforward way to annotate these IDs.
#
# **Steps to Annotate Gene IDs:**
# 1. **Use MyGeneInfo Library**: MyGeneInfo is a powerful tool for gene annotation. It allows you to query a database with Ensembl IDs and retrieve corresponding standard gene names.
# 2. **Query for Zebra Finch Genes**: Given that our study is on Zebra Finch, it's important to use the correct NCBI taxonomy ID (59729) for this species when querying.
# 3. **Merge Results with Original Data**: After obtaining the gene names, you can merge this information back into your dataset, linking each Ensembl ID to its standard gene name.
#
# **Python Implementation**:
# If you wish to perform this annotation, you can use the Python library `mygene`. Initialize a `MyGeneInfo` object, query using your list of Ensembl IDs, and then merge the results with your dataset. This process adds a column for gene names, enhancing the readability and interpretability of your data.
#
# Remember, while this annotation adds clarity, the original Ensembl IDs are crucial for maintaining the accuracy and precision of genomic data.

# %%
import mygene

#column of dataframe
ensembl_ids = transformed_df.columns[4:]
print(ensembl_ids)

def convert_ensemblId_to_gene_names(ensembl_ids):
    mg = mygene.MyGeneInfo()
    query_results = mg.querymany(ensembl_ids, scopes='ensembl.gene', fields='symbol', species='59729')
    gene_names = [result['symbol'] if 'symbol' in result else None for result in query_results]
    return gene_names

# Convert Ensembl IDs to gene names
gene_names = convert_ensemblId_to_gene_names(ensembl_ids)
print(gene_names)
# Out:
# Index(['ENSTGUG00000008284', 'ENSTGUG00000003938', 'ENSTGUG00000011987',
#        'ENSTGUG00000017592', 'ENSTGUG00000009442', 'ENSTGUG00000009764',
#        'ENSTGUG00000015152', 'ENSTGUG00000002407', 'ENSTGUG00000016201',
#        'ENSTGUG00000004296',
#        ...
#        'ENSTGUG00000010786', 'ENSTGUG00000004644', 'ENSTGUG00000006386',
#        'ENSTGUG00000017785', 'ENSTGUG00000001573', 'ENSTGUG00000014656',
#        'ENSTGUG00000003563', 'ENSTGUG00000002845', 'ENSTGUG00000009990',
#        'ENSTGUG00000001666'],
#       dtype='object', length=18618)
# 19 input query terms found dup hits:	[('ENSTGUG00000010166', 2), ('ENSTGUG00000011583', 2), ('ENSTGUG00000003913', 2), ('ENSTGUG000000022
# 7586 input query terms found no hit:	['ENSTGUG00000008284', 'ENSTGUG00000015152', 'ENSTGUG00000016201', 'ENSTGUG00000003903', 'ENSTGUG000
# [None, 'VASN', 'LAPTM4B', 'MIR125-2', 'PSMD6', 'CD38', None, 'SEMA3D', None, 'ATP2B2', None, None, 'CRIM1', None, None, 'LNPEP', 'GJA5', 'NME5', 'IL22', 'SCIN', None, 'RPP30', None, 'CAPRIN2', None, 'LOC100221970', 'CDKL2', None, 'TMEM201', None, 'RGP1', None, None, 'SPG11', 'SCRN1', None, 'AMT', 'MATN2', None, None, None, 'FRMD4B', None, None, 'KLC4', 'GARRE1', 'GLYR1', 'LOC100226456', 'MOV10', None, None, None, None, None, 'SFXN3', None, None, 'MIR375', 'KAT7', 'ONECUT1', None, 'GIT2', 'FMN2', None, 'UVSSA', None, 'VIT2', None, 'AGXT', 'ADPRHL1', 'LOC100218721', 'ASAH1', None, 'OLFML1', None, 'CIMIP1', None, 'LOC115495610', None, None, 'USP4', 'SCD5', None, 'FAM120A', None, 'CHMP4B', None, 'NCAPG', 'LOC100222183', 'RNGTT', 'MYO1E', 'ATAD2', 'KLHL22', 'UBE2J1', 'TUBGCP4', 'LOC115491411', 'LOC100229710', None, 'PDGFD', 'TBL1X', 'CEP170B', None, 'SNTB1', 'CD80', 'GYG2', None, None, 'C3H1orf198', 'NEDD4', 'PLAGL1', 'BBS4', None, None, 'DMGDH', None, 'SGTA', None, 'CSMD1', 'TPP2', None, 'PSMD14', None, 'FAM98B', 'RASGEF1B', 'GRIA1', 'TAF5L', 'RBM22', 'TMEM82', None, None, 'TECRL', 'CCDC6', 'FBXL2', None, 'BCL2A1', None, 'GMEB2', None, None, 'ZFPM2', 'LOC101233052', 'HERC4', None, None, 'LRP1B', 'RPS16', 'MMP17', None, 'DDO', None, 'SLC8A1', None, 'DHX36', None, None, None, 'GRIFIN', None, 'TAX1BP1', 'MB', None, 'BBX', 'RFWD3', 'NRG1', None, 'MIR193B', 'PTRH2', None, None, None, 'CALHM1', 'SCRG1', None, 'CHP1', 'L3HYPDH', 'FNIP1', None, 'KLHL2', None, None, None, None, 'AKAP6', 'CEP250', 'ENPP6', 'UBE2D3', 'IRF2', 'LOC100229447', None, None, None, None, 'SH3GL2', None, None, 'COMMD8', None, None, None, 'HDAC10', None, 'NEK2', 'LMO1', None, None, 'STYXL2', None, None, None, None, 'SLC25A36', 'PLPPR5', None, 'HTR1F', None, None, None, 'HBAA', 'ANAPC5', 'BTG4', 'HTRA3', None, None, None, None, 'FBLN7', None, None, 'CDR2L', 'TEX14', None, 'CA8', 'ATP9B', 'IMPDH2', None, None, None, 'CFAP418', 'ADAD1', 'TMEM252', 'C1QTNF8', 'TTC13', None, None, None, 'SVEP1', 'PLPP5', 'CELSR2', None, 'PMEL', None, 'TTC36', 'LOC101233947', None, 'TNNT3', 'KSR1', 'PDE7B', 'TNFRSF11B', None, 'ORC6', 'ZFYVE9', None, None, 'LOC100222002', 'CCDC77', 'FAF2', None, None, None, None, 'LOC115497185', 'SCG2', None, 'LOC100232471', None, None, 'GPX3', 'GRIP2', 'CDK1', 'FLNC', 'TKT', 'KIAA1614', 'TOMM70', None, None, 'LRRFIP2', 'ASZ1', None, None, 'VPREB3', 'GAB2', 'KIF20A', 'JHY', 'TFAP2A', 'LOC100222777', None, None, 'ETV4', 'LOC100225394', None, 'PELI1', None, None, 'SYAP1', 'LOC115496482', None, 'STOM', None, 'LOC100229646', 'DMAC2L', None, 'GAREM1', None, None, 'LHFPL4', 'VAX1', None, 'CDIN1', 'SNX30', None, 'NPAS3', 'POU1F1', None, None, 'CCDC91', None, 'MGAT4C', 'DLG5', None, 'NCOR1', 'IQCE', None, None, 'IDS', 'UCKL1', 'LOC100221958', None, 'CD274', 'FAM83F', None, 'JARID2', 'WDR4', 'ZBTB24', 'SLCO3A1', 'DCXR', 'TOP3A', 'IRF2BP2', 'FANCM', 'NOC3L', 'MKRN1', None, 'LOC100222415', None, None, 'KLF15', 'LOC105759204', 'YIPF3', None, None, None, None, None, 'SLC16A4', None, None, 'LOC100218246', 'SYNPR', None, 'HNRNPA3', None, 'DAG1', 'FSD2', 'DCDC2', None, 'LZTR1', None, None, None, None, 'SLC35B1', None, 'SCLY', 'KLHL30', 'LSAMP', None, None, None, 'TNKS', 'AP2B1', 'SMG6', None, 'METTL5', 'LOC115497779', 'FAT1', None, 'TRERF1', None, 'DIRAS1', None, None, 'BBS9', 'WDR72', None, None, 'TGFBR1', None, 'EXOSC9', None, 'POLR1E', None, None, 'SLC30A9', None, 'LOC101233949', 'PDSS2', None, None, None, 'IKZF3', None, None, 'ZNF142', 'CENPU', 'ZMYM4', 'MMAB', None, 'OXR1', 'SLC39A10', None, 'LOC115495694', 'PDCD7', None, None, None, None, None, None, 'PHC1', 'ACOX3', None, 'LOC100226671', None, None, None, 'STX19', 'NOL9', 'BICD2', 'TUBGCP2', 'ATL2', 'CUX1', None, 'LOC115494208', 'CYP19A1', 'SPDL1', None, 'CHMP3', None, None, None, 'LOC100219615', None, 'PITX2', None, 'INSC', None, 'LOC100219822', None, 'CHRNG', 'CGA', None, None, 'PDE8A', 'IL17REL', 'TERF1', None, 'SMDT1', 'SLC49A4', None, 'SLC36A4', 'RHCG', 'MXD4', 'PPP1R7', None, 'STXBP6', 'LOC100217703', None, No ...

# %% [markdown]
# ### Normalization of RNA-Seq Data: Ensuring Accurate Comparisons
#
# Normalization is a crucial step in data analysis. In this context, it corrects for variations in sequencing depth and gene length across samples, enabling accurate comparisons of gene expression levels. Without normalization, differences in read counts could be mistakenly attributed to biological variation instead of technical biases.
#
# **Why Normalize?**
# - **Sequencing Depth Variability**: Different samples might have varying total numbers of reads due to differences in sequencing efficiency. Normalization adjusts for these discrepancies.
# - **Gene Length Bias**: Longer genes tend to have more reads merely due to their size. Normalization methods like TPM (Transcripts Per Million) correct for this by accounting for gene length.
#
# **Normalization Method - Counts Per Million (CPM)**:
# - We'll use the CPM method for its simplicity and effectiveness. CPM normalizes gene expression measurements by dividing the read counts of each gene by the total read counts per million in each sample. This method is suitable for datasets where the focus is on comparing expression patterns rather than quantifying absolute expression levels.
#
# **Implementing CPM in Python**:
# The following Python code demonstrates how to apply CPM normalization to our dataset. It involves calculating the total read counts for each sample, normalizing each gene's read count, and then multiplying by one million.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('./dataset/transformed_dataset.csv')

# Function to calculate CPM
def calculate_cpm(df):
    total_reads = df.sum(axis=0)
    cpm = (df / total_reads) * 1e6
    cpm = cpm.fillna(0.0)
    return cpm

def normalize_df(df):
    metadata_cols = ['sample_id', 'social_settting', 'study_group', 'tissue_id']
    expression_data = df.drop(columns=metadata_cols)
    normalized_df = calculate_cpm(expression_data)

    # Combine the normalized data with the metadata
    normalized_df = pd.concat([df[metadata_cols], normalized_df], axis=1)
    return normalized_df
normalized_df = normalize_df(df)

# Save the normalized dataset
normalized_df.to_csv('./dataset/normalized_dataset.csv', index=False)

# Display the first few rows of the normalized dataset
display(normalized_df.head())
# Out:
#     sample_id social_settting study_group tissue_id  ENSTGUG00000008284  \
# 0  GSM6175777              NF           L       HY3         7916.143473
# 1  GSM6175779             ISO           S       HY5         8134.519845
# 2  GSM6175780             ISO           L       HY6         6605.885243
# 3  GSM6175781             ISO           L       HY8         8680.460774
# 4  GSM6175782             ISO           L       HY9         9390.183982
#
#    ENSTGUG00000003938  ENSTGUG00000011987  ENSTGUG00000017592  \
# 0         5231.219920         8352.808004         5319.148936
# 1         4394.224733         8562.769298         5319.148936
# 2         6068.215108         5824.143723        14893.617021
# 3         4603.473530         8215.876725         5319.148936
# 4         7951.454279         6837.435186         4255.319149
#
#    ENSTGUG00000009442  ENSTGUG00000009764  ...  ENSTGUG00000010786  \
# 0         6991.276372         7795.007878  ...         9225.899161
# 1         6836.602116         6302.346795  ...         6810.088094
# 2         7950.256759        10448.627581  ...         7289.085116
# 3         6248.839943        14760.759599  ...         8705.250224
# 4         6094.165687         7795.007878  ...         5706.312348
#
#    ENSTGUG00000004644  ENSTGUG00000006386  ENSTGUG00000017785  \
# 0         8094.573516        10803.531348                 0.0
# 1         7109.432723         7825.826725                 0.0
# 2         6075.034890         5910.519228                 0.0
# 3         7142.270750         5820.739189                 0.0
# 4         5615.302520         4354.331887                 0.0
#
#    ENSTGUG00000001573  ENSTGUG00000014656  ENSTGUG00000003563  \
# 0            0.000000            0.000000         4415.388212
# 1            0.000000            0.000000         4562.268065
# 2        10695.187166         3636.363636         3956.763368
# 3       139037.433155        18181.818182         4622.219025
# 4            0.000000        18181.818182         3797.893323
#
#    ENSTGUG00000002845  ENSTGUG00000009990  ENSTGUG00000001666
# 0         5699.138502         9239.730843        13426.303687
# 1         4903.909874         4854.206421         8753.059862
# 2         2915.838304         5825.047705         8159.632075
# 3         7554.671968         7331.525560         8604.702915
# 4         3180.914513         5255.933849         6527.705660
#
# [5 rows x 18622 columns]

# %% [markdown]
# ### Exploratory Data Analysis: Uncovering Patterns in Gene Expression
#
# Exploratory Data Analysis (EDA) is an essential phase in RNA-Seq data analysis, aimed at visualizing and summarizing data to uncover underlying patterns and trends. For this demonstration, we'll focus on visualizing gene expression differences across study groups ('L' for LPS treatment and 'S' for control) and social settings.
#
# **Key Focus Areas for Our Visualization:**
# 1. **Comparing 'L' and 'S' Study Groups**: This helps us understand the impact of LPS treatment versus control on gene expression.
# 2. **Role of Social Settings**: We'll also explore how different social interactions might influence gene expression patterns.
#
# This demonstration is a starting point for EDA. You are encouraged to explore various aspects of the data through diverse visualizations and analyses.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the normalized dataset
df = pd.read_csv('./dataset/normalized_dataset.csv')

# Select a gene for visualization (example: 'ENSTGUG00000004743', which is Brain-Derived Neurotrophic Factor gene)
selected_gene = 'ENSTGUG00000004743'

# Map the social setting abbreviations to full descriptions
social_setting_map = {
    'ISO': 'Isolated',
    'KFC': 'Known Female Continuous',
    'KF': 'Known Female Reunited',
    'NF': 'Novel Female'
}
df['social_settting'] = df['social_settting'].map(social_setting_map)

# Create a boxplot comparing gene expression across study groups and social settings
plt.figure(figsize=(12, 6))
sns.boxplot(x='social_settting', y=selected_gene, hue='study_group', data=df, palette="Set2")
plt.title('Gene Expression of ' + selected_gene + ' Across Study Groups and Social Settings')
plt.ylabel('Expression Level (CPM)')
plt.xlabel('Social Setting')
plt.legend(title='Study Group')
plt.show()

# %% [markdown]
# **Write down your interpretation of the result of this simple barplot, that displays expression level of `BDNF` gene. First, briefly describe `BDNF` and it's function. Then, write your interpretation about any notable observation you see from the plot**
#
# **_Your Answer_**:
#
# The BDNF gene, is a gene that encodes the BDNF protein. BDNF, short for brain-derived neurotrophic factor, is a secreted protein and a member of the neurotrophin family. It plays a vital role in the growth, development, and maintenance of neurons in the brain by providing trophic support and promoting their survival and differentiation. BDNF is essential for neuronal growth, the formation of new neurons, and the development of synapses, which are crucial for proper brain function.
#
# From the barplot provided, which compares the expression level of the BDNF gene across different study groups and social settings, we can make several observations:
#
# - Variation in Expression Levels: The gene expression levels of BDNF appear to vary across different social settings.
# - Social Setting Influence:
#    - In the 'Novel Female' and 'Isolated' settings, group 'L' shows a higher median expression level than group 'S'.
#    - Conversely, in the 'Known Female Reunited' and 'Known Female Continuous' settings, group 'S' has a slightly higher median expression than group 'L', although the difference seems less pronounced.
# - Outliers and Variability:
#    - There are several outliers, particularly in the 'Novel Female' and 'Isolated' categories for both groups, indicating some individuals have much higher BDNF expression levels than the majority.
#    - The variability, as shown by the length of the whiskers, is quite large in all categories, but particularly so in 'Novel Female' and 'Known Female Continuous', suggesting a wide range of responses in BDNF gene expression within these settings.
# - Potential Implications:
#    - The BDNF expression levels are generally lower in social settings with 'Known Female' compared to 'Novel Female' and 'Isolated', which might suggest that social familiarity or social isolation impacts BDNF expression.
#    - The fact that 'Known Female Continuous' has a lower expression than 'Known Female Reunited' for group 'L' might indicate that continuous social interaction has a different impact on BDNF expression compared to a reunion after isolation.
#
#
# <blockquote style="font-family:Arial; color:red; font-size:16px; border-left:0px solid red; padding: 10px;">
#     <strong>Don't forget to answer this question!</strong>
# </blockquote>

# %% [markdown]
# ### Diverse Visualization Techniques for Gene Expression Data
#
# A comprehensive exploration of gene expression data requires a multifaceted visualization approach. Beyond the boxplot, we will delve into additional techniques that can bring forth deeper insights from our dataset. You are tasked with implementation and interpretation of the results of at least one of the following visualization methods:
#
# - **PCA (Principal Component Analysis)**: This technique reduces the dimensionality of the data and can reveal the underlying structure by capturing the most variation across samples.
# - **t-SNE (t-Distributed Stochastic Neighbor Embedding)**: Particularly useful for visualizing high-dimensional data in a lower-dimensional space, t-SNE can help identify clusters of genes or samples.
# - **UMAP (Uniform Manifold Approximation and Projection)**: Similar to t-SNE, UMAP is useful for visualization and can be faster and more scalable.
#
# In addition to these, consider the following methods to further dissect the dataset:
#
# - **Histograms and Density Plots**: Useful for showing the distribution of gene expression levels within individual samples or conditions.
# - **Boxplots and Violin Plots**: These can summarize the distributions and highlight potential outliers in gene expression levels across samples.
# - **Scatter Plots**: When exploring the relationship between different conditions, scatter plots can be particularly revealing.
# - **Volcano Plots**: Ideal for showcasing differential expression results, highlighting genes with significant fold changes and statistical significance.
#
# Each method will contribute to a holistic view of the dataset, enabling you to uncover patterns and anomalies that may not be apparent through a single visualization strategy.

# %% [markdown]
# #### **Your Turn to Explore**
#
# - **Experiment with Different Genes**: Change the `selected_gene` variable to analyze other genes of interest.
# - **Diverse Visualizations**: Consider using heatmaps, violin plots, or scatter plots for different perspectives.
# - **Incorporate Statistical Analyses**: Complement visual insights with statistical tests to discern if the differences you observe are significant.
#
# Remember, the goal is to thoroughly understand the dataset, paving the way for more in-depth analyses like differential gene expression or clustering.

# %%
# analyze fixed_gene expression across study groups and social settings
from scipy.stats import ttest_ind
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.manifold import TSNE


def box_plot_gene_expression(df, selected_gene):
    normalized_df = normalize_df(df)

    # Map the social setting abbreviations to full descriptions
    social_setting_map = {
        'ISO': 'Isolated',
        'KFC': 'Known Female Continuous',
        'KF': 'Known Female Reunited',
        'NF': 'Novel Female'
    }
    normalized_df['social_settting'] = normalized_df['social_settting'].map(social_setting_map)

    # Create a boxplot comparing gene expression across study groups and social settings
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='social_settting', y=selected_gene, hue='study_group', data=normalized_df, palette="Set2")
    plt.title('Gene Expression of ' + selected_gene + ' Across Study Groups and Social Settings')
    plt.ylabel('Expression Level (CPM)')
    plt.xlabel('Social Setting')
    plt.legend(title='Study Group')
    plt.show()

def hist_plot_gene_expression(df, selected_gene, social_setting):
    normalized_df = normalize_df(df)

    # Filter the data for the selected gene and social setting
    filtered_df_L = normalized_df[(normalized_df['social_settting'] == social_setting) & (normalized_df['study_group'] == 'L')]
    plt.figure(figsize=(12, 6))
    sns.histplot(filtered_df_L[selected_gene], kde=True, bins=20, color='blue', label='L Group')

    # Filter the data for the selected gene and social setting
    filtered_df_S = normalized_df[(normalized_df['social_settting'] == social_setting) & (normalized_df['study_group'] == 'S')]
    sns.histplot(filtered_df_S[selected_gene], kde=True, bins=20, color='red', label='S Group')
    plt.title('Gene Expression of ' + selected_gene + ' in ' + social_setting + ' Social Setting')

def t_test_for_gene_expression(df, selected_gene, social_setting):
    normalized_df = normalize_df(df)
    # Filter the data for the selected gene and social setting
    filtered_df_L = normalized_df[(normalized_df['social_settting'] == social_setting) & (normalized_df['study_group'] == 'L')]
    filtered_df_S = normalized_df[(normalized_df['social_settting'] == social_setting) & (normalized_df['study_group'] == 'S')]

    # Perform a t-test
    t_stat, p_val = ttest_ind(filtered_df_L[selected_gene], filtered_df_S[selected_gene])
    print(f'result of t-test for {selected_gene} in {social_setting} social setting:')
    print('     T-statistic:', t_stat)
    print('     P-value:', p_val)

def plot_pca(df):
    normalized_df = normalize_df(df)
    expression_data = normalized_df.drop(columns=['sample_id', 'social_settting', 'study_group', 'tissue_id'])

    pca = PCA(n_components=2)
    principal_components = pca.fit_transform(expression_data)
    pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

    # Add the metadata columns to the PCA dataframe
    pca_df = pd.concat([df[['sample_id', 'social_settting', 'study_group', 'tissue_id']], pca_df], axis=1)

    plt.figure(figsize=(12, 8))
    plt.title('Principal Component Analysis (PCA)')
    sns.scatterplot(x='PC1', y='PC2', hue='social_settting', style='study_group', data=pca_df, palette='Set2')

    # Calculate the percentage of variance explained by each principal component
    explained_variance_ratio = pca.explained_variance_ratio_

    # Create a scree plot
    plt.figure(figsize=(12, 6))
    sns.barplot(x=['PC1', 'PC2'], y=explained_variance_ratio, palette='Set2')
    plt.title('Scree Plot')
    plt.xlabel('Principal Component')
    plt.ylabel('Explained Variance Ratio')
    plt.show()


def plot_pca_for_fixed_social_settting(df, social_setting):
    normalized_df = normalize_df(df)
    expression_data = normalized_df.drop(columns=['sample_id', 'social_settting', 'study_group', 'tissue_id'])
    # Perform PCA
    pca = PCA(n_components=2)
    principal_components = pca.fit_transform(expression_data)

    pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

    # Add the metadata columns to the PCA dataframe
    pca_df = pd.concat([df[['sample_id', 'social_settting', 'study_group', 'tissue_id']], pca_df], axis=1)

    # Plot the PCA results for only the 'ISO' social setting
    plt.figure(figsize=(12, 8))
    plt.title('Principal Component Analysis (PCA) for ' + social_setting + ' Social Setting')
    sns.scatterplot(x='PC1', y='PC2', hue='study_group', data=pca_df[pca_df['social_settting'] == social_setting], palette='Set2')
    
def plot_tsne(df):
    normalized_df = normalize_df(df)
    expression_data = normalized_df.drop(columns=['sample_id', 'social_settting', 'study_group', 'tissue_id'])

    scaler = StandardScaler()
    expression_scaled = scaler.fit_transform(expression_data)

    # Perform t-SNE
    tsne = TSNE(n_components=2, random_state=42)
    tsne_results = tsne.fit_transform(expression_scaled)

    # Create a dataframe containing the t-SNE results
    tsne_df = pd.DataFrame(data=tsne_results, columns=['t-SNE1', 't-SNE2'])
    tsne_df = pd.concat([df[['sample_id', 'social_settting', 'study_group', 'tissue_id']], tsne_df], axis=1)

    # Plot the t-SNE results
    plt.figure(figsize=(12, 8))
    plt.title('t-Distributed Stochastic Neighbor Embedding (t-SNE)')
    sns.scatterplot(x='t-SNE1', y='t-SNE2', hue='social_settting', style='study_group', data=tsne_df, palette='Set2')
    plt.show()

    #t-Distributed Stochastic Neighbor Embedding (t-SNE) with respect to social_settting
    plt.figure(figsize=(12, 8))
    plt.title('t-Distributed Stochastic Neighbor Embedding (t-SNE) with respect to social_settting')
    sns.scatterplot(x='t-SNE1', y='t-SNE2', hue='social_settting', data=tsne_df, palette='Set2')
    plt.show()

    #t-Distributed Stochastic Neighbor Embedding (t-SNE) with respect to social_settting and study_group
    plt.figure(figsize=(12, 8))
    plt.title('t-Distributed Stochastic Neighbor Embedding (t-SNE) with respect to social_settting and study_group')
    sns.scatterplot(x='t-SNE1', y='t-SNE2', hue='study_group', data=tsne_df, palette='Set2')
    plt.show()
    
def plot_heatmap(df):
    # mean of read for each type of social_setting and region and plot heatmap
    normalized_df = normalize_df(df)
    normalized_df['Region'] = normalized_df['tissue_id'].apply(lambda x: x[:2])
    expression_data = normalized_df.drop(columns=['sample_id', 'study_group', 'tissue_id', 'Region', 'social_settting'])

    social_setting_map = ['ISO','KFC','KF','NF']
    regions = normalized_df['Region'].unique()

    # mean of read for each type of social_setting and region and create dataframe
    new_dict = dict()
    for social_setting in social_setting_map:
        for region in regions:
            mean_expression = expression_data[(normalized_df['social_settting'] == social_setting) & (normalized_df['Region'] == region) & (normalized_df['study_group'] == 'L')].mean().mean()
            new_dict[(region, social_setting)] = mean_expression

    heatmap_data = pd.DataFrame(list(new_dict.values()), index=pd.MultiIndex.from_tuples(new_dict.keys(), names=['Region', 'Social Setting']), columns=['Mean Expression'])
    heatmap_data = heatmap_data.pivot_table(index='Region', columns='Social Setting', values='Mean Expression')
    plt.figure(figsize=(10, 8))
    sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f", linewidths=.5)
    plt.title('Mean Expression Heatmap by Region and Social Setting for L Group')
    plt.show()
    

    new_dict = dict()
    for social_setting in social_setting_map:
        for region in regions:
            mean_expression = expression_data[(normalized_df['social_settting'] == social_setting) & (normalized_df['Region'] == region) & (normalized_df['study_group'] == 'S')].mean().mean()
            new_dict[(region, social_setting)] = mean_expression

    heatmap_data = pd.DataFrame(list(new_dict.values()), index=pd.MultiIndex.from_tuples(new_dict.keys(), names=['Region', 'Social Setting']), columns=['Mean Expression'])
    heatmap_data = heatmap_data.pivot_table(index='Region', columns='Social Setting', values='Mean Expression')
    plt.figure(figsize=(10, 8))
    sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f", linewidths=.5)
    plt.title('Mean Expression Heatmap by Region and Social Setting for S Group')
    plt.show()


    

# Load the dataset
df = pd.read_csv('./dataset/transformed_dataset.csv')
selected_gene = 'ENSTGUG00000008284'
box_plot_gene_expression(df, selected_gene)
hist_plot_gene_expression(df, selected_gene, 'ISO')
t_test_for_gene_expression(df, selected_gene, 'ISO')
plot_pca_for_fixed_social_settting(df, 'KFC')
plot_pca(df)
plot_tsne(df)
plot_heatmap(df)
# Out:
# result of t-test for ENSTGUG00000008284 in ISO social setting:
#      T-statistic: -0.04832068347600576
#      P-value: 0.9617519385242862
# /tmp/ipykernel_84624/3550108971.py:75: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['PC1', 'PC2'], y=explained_variance_ratio, palette='Set2')

# %% [markdown]
# ### Reflecting on Visualizations to Extract Key Insights
#
# As we have navigated through different visualization strategies, it's time to consolidate the knowledge you've gained. Reflect on the insights each visualization has provided:
#
# - **What trends have you observed in the distribution of gene expression levels?**
# - **How do the expression levels compare when you look across different conditions or samples?**
# - **From the heatmap, were you able to detect any consistent patterns of expression, such as upregulation or downregulation of certain genes?**
# - **Did any outliers or unusual expression patterns emerge? What might these suggest about certain genes or the overall data quality?**
#
# Write down your observations and hypotheses. Discuss and note down your interpretations as they will be valuable for the upcoming stages of differential gene expression analysis.
#
# **_Your Answer_**:
#
# As you can see, we have employed various methods for visually inspecting the data. In the initial stage, we once again used box plots to draw graphs for different genes, aiming to reexamine the analyses conducted in the previous section. Following that, we drew a histogram for a specific gene across two different groups, visually indicating that the mean expressions in one group are higher than the other. Therefore, subsequent to conducting a t-test, we realized that there is a high level of uncertainty, and thus, our hypothesis was not substantiated.
#
# Afterward, we attempted to discern whether reducing dimensions through t-SNE and PCA would reveal any latent relationships based on experimental groups or social status. However, based on observations, we did not identify a specific pattern that would lead us to a clustering scenario.
#
# Finally, we created a heatmap based on brain regions and social status. It was interesting to note that this heatmap complemented each other to some extent for the two experimental groups.

# %% [markdown]
# ---

# %% [markdown]
# ### Differential Gene Expression Analysis
#
# After exploring the general patterns in our dataset, the next step is Differential Gene Expression (DGE) analysis. This process will help us identify genes whose expression levels significantly differ across treatments or social settings.
#
# #### Addressing High Dimensionality in RNA-Seq Data for Differential Gene Expression Analysis
#
# In RNA-Seq data, high dimensionality (a large number of genes) presents several analytical challenges. This complexity can obscure meaningful biological insights and impact the statistical power of our analyses.
#
# **Challenges of High Dimensionality**:
# 1. **Statistical Power Loss**: With too many variables (genes), the risk of finding false positives increases, known as the 'multiple testing problem'.
# 2. **Overfitting Risk**: High-dimensional data can lead to models that are too complex, capturing noise rather than true underlying patterns.
# 3. **Computational Intensity**: Analyzing thousands of genes simultaneously demands significant computational resources and time.
# 4. **Interpretation Difficulty**: It becomes challenging to interpret results and extract biologically meaningful conclusions from a vast pool of data.
#
# **Addressing These Challenges**:
# 1. **Dimensionality Reduction**: Techniques like PCA (Principal Component Analysis) and t-SNE (t-Distributed Stochastic Neighbor Embedding) help in reducing the number of dimensions, making the data more manageable and revealing hidden structures.
# 2. **RNA-Seq Specific Tools for DGE Analysis**: Tools like DESeq2 and edgeR (available in Python through rpy2 or similar interfaces) are designed to handle high-dimensional data. They offer:
#    - **Normalization and Variance Stabilization**: Tailored for RNA-Seq data, ensuring fair comparisons across samples.
#    - **FDR Control**: Implement procedures to adjust for multiple comparisons, reducing false positives.
#    - **Biological Variance Modeling**: Consider the biological variability, enhancing the reliability of results.
#
# **Python Implementation**:
# - In python environments, the use of R-based tools like DESeq2 or edgeR is possible through interfaces such as `rpy2`. This approach allows you to leverage the strengths of these tools while working within a Python framework. However, as stated multiple times in this project, you have freedom to choose alternative method for any task, as long as it makes sense.

# %%
### TODO ###
# Placeholder for PCA Analysis. 

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Note: Before applying PCA, it's important to standardize the data
# Example: Standardize the gene expression data (excluding metadata columns)

# Load your expression data here
# expression_data = ...
df = pd.read_csv('./dataset/transformed_dataset.csv')
expression_data = df.drop(columns=['sample_id', 'social_settting', 'study_group', 'tissue_id'])

# Standardize the data
scaler = StandardScaler()
expression_scaled = scaler.fit_transform(expression_data)

# Apply PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(expression_scaled)

pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
pca_df = pd.concat([df[['sample_id', 'social_settting', 'study_group', 'tissue_id']], pca_df], axis=1)

# Plot the PCA results
# Principal Component Analysis (PCA) with respect to social_settting and study_group
plt.figure(figsize=(12, 8))
plt.title('Principal Component Analysis (PCA) with respect to social_settting and study_group')
sns.scatterplot(x='PC1', y='PC2', hue='social_settting', style='study_group', data=pca_df, palette='Set2')
plt.show()


#Principal Component Analysis (PCA) with respect to social_settting
plt.figure(figsize=(12, 8))
plt.title('Principal Component Analysis (PCA) with respect to social_settting')
sns.scatterplot(x='PC1', y='PC2', hue='social_settting', data=pca_df, palette='Set2')
plt.show()

#Principal Component Analysis (PCA) with respect to social_settting and study_group
plt.figure(figsize=(12, 8))
plt.title('Principal Component Analysis (PCA) with respect to social_settting and study_group')
sns.scatterplot(x='PC1', y='PC2', hue='study_group', data=pca_df, palette='Set2')
plt.show()

def explore_variance_ratio(df, n_components):
    expression_data = df.drop(columns=['sample_id', 'social_settting', 'study_group', 'tissue_id'])

    # Standardize the data
    scaler = StandardScaler()
    expression_scaled = scaler.fit_transform(expression_data)

    # Apply PCA
    pca = PCA(n_components=n_components)
    pca.fit(expression_scaled)

    # Plot the scree plot
    plt.figure(figsize=(12, 6))
    sns.barplot(x=[f'PC{i+1}' for i in range(n_components)], y=pca.explained_variance_ratio_, palette='Set2')
    plt.title(f'Scree Plot for components={n_components}')
    plt.xlabel('Principal Component')
    plt.ylabel('Explained Variance Ratio')
    plt.show()

explore_variance_ratio(df, 2)
explore_variance_ratio(df, 3)
explore_variance_ratio(df, 10)
explore_variance_ratio(df, 20)
# Out:
# /tmp/ipykernel_84624/1677691583.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=[f'PC{i+1}' for i in range(n_components)], y=pca.explained_variance_ratio_, palette='Set2')
# /tmp/ipykernel_84624/1677691583.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=[f'PC{i+1}' for i in range(n_components)], y=pca.explained_variance_ratio_, palette='Set2')
# /tmp/ipykernel_84624/1677691583.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=[f'PC{i+1}' for i in range(n_components)], y=pca.explained_variance_ratio_, palette='Set2')
# /tmp/ipykernel_84624/1677691583.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=[f'PC{i+1}' for i in range(n_components)], y=pca.explained_variance_ratio_, palette='Set2')

# %%
### TODO ###
# Placeholder for using a common RNA-Seq analysis tool from Python

import subprocess

# Example: Using DESeq2 via R for Differential Gene Expression Analysis
# DESeq2 is a popular tool for RNA-Seq data, particularly useful for identifying differentially expressed genes

# Define the paths and necessary arguments
r_script_path = './dataset/deseq2_analysis.R' 
input_file_path = './dataset/normalized_dataset.csv'  # CSV file path
output_file_path = './dataset/deseq2_output.csv'      # Path to save the DESeq2 output

# Construct the command to run the R script using subprocess
command = ['Rscript', r_script_path, input_file_path, output_file_path]

# Run the command
subprocess.run(command)

# Tips and Hints:
# - Ensure that R and DESeq2 are installed in your environment.
# - The R script should be written to take input and output file paths as arguments.
# - The script should handle the reading of the CSV file, applying DESeq2, and writing the results back to a CSV.
# - In the R script, consider using additional metadata columns (like 'study_group', 'social_settting') as part of the DESeq2 design formula to account for these factors in the analysis.
# - You can capture the output and errors from the subprocess to check if the script ran successfully.
# - For Python users not familiar with R, consider using Python alternatives or interfaces such as rpy2 to work with DESeq2.
# Out:
# Fatal error: cannot open file 'path/to/deseq2_analysis.R': No such file or directory
# CompletedProcess(args=['Rscript', 'path/to/deseq2_analysis.R', 'path/to/normalized_dataset.csv', 'path/to/deseq2_output.csv'], returncode=2)

# %% [markdown]
# ### Identifying Differentially Expressed Genes (DEGs)
#
# The core of our RNA-Seq analysis lies in identifying Differentially Expressed Genes (DEGs) between different conditions, such as LPS treatment vs control, and across social settings. Identifying DEGs helps in pinpointing specific genes that are responsive to our experimental treatments.
#
# **Freedom in Methodology**:
# - You are free to choose your preferred method or tool for DEG analysis. Whether it's DESeq2, edgeR, or any other method, the key is to reliably identify genes that show statistically significant differences in expression.
#
# ### Interpreting the Findings
#
# After identifying DEGs, the next crucial step is interpreting these findings. This involves understanding the biological functions and pathways these genes are involved in.
#
# **Functional Annotation and Pathway Analysis**:
# - Utilize databases like Gene Ontology (GO), Kyoto Encyclopedia of Genes and Genomes (KEGG), or DAVID for functional annotation.
# - Interpret the roles of these genes in biological processes, cellular components, and molecular functions.
#
# ### Visualization for Insightful Understanding
#
# A critical aspect of this phase is visualization. Effective visualizations can provide profound insights into the data and help in communicating your findings.
#
# **Visualizations Can Include**:
# - Heatmaps of DEGs.
# - Volcano plots showing the significance vs. fold-change.
# - Pathway diagrams to illustrate the affected biological pathways.
#
# ### Emphasis on Interpretation and Informative Visualization
#
# Remember, the ultimate goal is to not only identify DEGs but to also understand their biological significance and visually represent this information in an insightful and informative manner. Your interpretations and visualizations are crucial for translating raw data into meaningful biological insights.

# %%
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
import scanpy as sc
import gseapy as gp
from gseapy.plot import gseaplot

# Read the dataset
df = pd.read_csv('./dataset/transformed_dataset.csv')
df = df.dropna()

numeric_columns = df.select_dtypes(include='number').columns

# Filter columns where the sum is non-zero
zero_sum_columns = df[numeric_columns].columns[df[numeric_columns].sum() == 0]
df = df.drop(columns=zero_sum_columns)
transformed_df = df 

# Remove unnecessary columns for DESeq2 analysis
data = df.drop(columns=["social_settting", "study_group", "tissue_id"])
data = data.set_index('sample_id')

# Create a subset with relevant metadata for DESeq2
cmetadata = df[["sample_id", "social_settting", "study_group", "tissue_id"]]
cmetadata = cmetadata.set_index('sample_id')

# Create a DeseqDataSet
dds = DeseqDataSet(counts=data,
                   metadata=cmetadata,
                   design_factors="study_group")

dds.deseq2()
# Plot the PCA results with color based on the study group
sc.tl.pca(dds)
sc.pl.pca(dds, color = 'study-group', size = 100)

# Create a DeseqStats object for additional analysis
result = DeseqStats(dds, contrast=("study-group", 'L', 'S'))
result.summary()
# Extract DESeq2 results as a DataFrame
df_result = result.results_df

# Filter significantly differentially expressed genes
sigs_genes = df_result[(df_result.padj < 0.05) & (abs(df_result.log2FoldChange) > 0.5)]
# Out:
# /tmp/ipykernel_84624/649040016.py:27: UserWarning: Same factor names in the design contain underscores ('_'). They will
#                 be converted to hyphens ('-').
#   dds = DeseqDataSet(counts=data,
# Fitting size factors...
# ... done in 0.07 seconds.
#
# Fitting dispersions...
# ... done in 2.55 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.72 seconds.
#
# Fitting MAP dispersions...
# ... done in 3.24 seconds.
#
# Fitting LFCs...
# ... done in 1.89 seconds.
#
# Refitting 55 outliers.
#
# Fitting dispersions...
# ... done in 0.04 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.04 seconds.
#
# Fitting LFCs...
# ... done in 0.02 seconds.
#
# /home/mahdi/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# Running Wald tests...
# Log2 fold change & Wald test p-value: study-group L vs S
#                        baseMean  log2FoldChange     lfcSE      stat  \
# ENSTGUG00000008284   139.532688        0.018720  0.062971  0.297286
# ENSTGUG00000003938    35.967245        0.249501  0.100936  2.471867
# ENSTGUG00000011987   823.687055       -0.054608  0.052956 -1.031196
# ENSTGUG00000017592     7.233779       -0.403934  0.174887 -2.309689
# ENSTGUG00000009442   244.108581       -0.037595  0.054339 -0.691854
# ...                         ...             ...       ...       ...
# ENSTGUG00000014656     2.060085       -0.360486  0.338991 -1.063412
# ENSTGUG00000003563  2452.662301       -0.025376  0.090273 -0.281100
# ENSTGUG00000002845    57.097041        0.146948  0.106800  1.375923
# ENSTGUG00000009990   223.274451        0.263861  0.050759  5.198303
# ENSTGUG00000001666   102.317021        0.007181  0.065733  0.109250
#
#                           pvalue      padj
# ENSTGUG00000008284  7.662478e-01  0.918778
# ENSTGUG00000003938  1.344094e-02  0.094667
# ENSTGUG00000011987  3.024488e-01  0.623093
# ENSTGUG00000017592  2.090536e-02  0.128525
# ENSTGUG00000009442  4.890288e-01  0.772795
# ...                          ...       ...
# ENSTGUG00000014656  2.875953e-01  0.607692
# ENSTGUG00000003563  7.786336e-01  0.924872
# ENSTGUG00000002845  1.688455e-01  0.462408
# ENSTGUG00000009990  2.011163e-07  0.000007
# ENSTGUG00000001666  9.130045e-01  0.971081
#
# [18180 rows x 6 columns]
# ... done in 1.04 seconds.

# %%
dds_sigs = dds[:, sigs_genes.index]


grapher = pd.DataFrame(dds_sigs.layers['replace_cooks'].T,
                       index=dds_sigs.var_names, columns=dds_sigs.obs_names)
# Add a small value to avoid zero values in the heatmap
for i in range(grapher.shape[0]):
    for j in range(1, grapher.shape[1]):
        grapher.iloc[i, j] += 0.00000001

sns.clustermap(grapher, z_score=0, cmap = 'RdYlBu_r')
# Out:
# /home/mahdi/.local/lib/python3.10/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /home/mahdi/.local/lib/python3.10/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
### TODO ###
# Placeholder for DEG Analysis, Interpretation, and Visualization
# Step 1: DEG Analysis
# Use your chosen tool/method to identify DEGs
# Example: results = DESeq2_DEG_analysis(input_file)




# Step 2: Functional Annotation
# Utilize online databases or tools for gene annotation
# Example: annotated_genes = annotate_genes(results['gene_id'])

# Step 3: Pathway Analysis
# Map the DEGs to biological pathways
# Example: pathways = map_to_pathways(annotated_genes)

# Step 4: Visualization
# Create insightful visualizations of the DEGs
# Example: create_heatmap(results)
# Example: create_volcano_plot(results)
# Example: plot_pathways(pathways)

# Remember to interpret your findings in the context of the biological questions and hypotheses you are exploring.
# Consider the biological significance of the DEGs and their roles in the context of your study.
